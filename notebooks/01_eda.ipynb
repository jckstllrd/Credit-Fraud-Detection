# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import sys
print(sys.path)
# Out:
# ['/Users/jackstallard/.pyenv/versions/3.12.2/lib/python312.zip', '/Users/jackstallard/.pyenv/versions/3.12.2/lib/python3.12', '/Users/jackstallard/.pyenv/versions/3.12.2/lib/python3.12/lib-dynload', '', '/Users/jackstallard/.pyenv/versions/3.12.2/lib/python3.12/site-packages', '/Users/jackstallard/Documents/learning/AI Mastery/Credit-Fraud-Detection/src']

# %%
import os
cwd = os.getcwd()
print(cwd)
# Out:
# /Users/jackstallard/Documents/learning/AI Mastery/Credit-Fraud-Detection/notebooks

# %%
import fraud_detection.data_loader as dl
import matplotlib

# %%
raw_credit_data = "../data/raw/creditcard.csv"

# %%
df = dl.load_data(raw_credit_data)

# %%
print(dl.info_summary(df))
# Out:
# Data Shape: (284807, 31)
# Duplicate Rows: 1081

# %%
total_cases = len(df)
non_fraud_cases = len(df[df['Class'] == 0])
fraud_cases = len(df[df['Class'] == 1])

# %%
fraud_ratio = fraud_cases / total_cases

# %%
print(fraud_ratio * 100)
# Out:
# 0.1727485630620034

# %% [markdown]
# The fraud ratio is 0.17%, indicating an extremely unbalanced ratio of fraud cases to non-fraud. This can cause issues with overfitting and may need to be corrected during feature engineering.

# %%
print(df['Amount'].describe())
# Out:
# count    284807.000000
# mean         88.349619
# std         250.120109
# min           0.000000
# 25%           5.600000
# 50%          22.000000
# 75%          77.165000
# max       25691.160000
# Name: Amount, dtype: float64

# %%
df['Amount'].hist(bins=100, log=True)
# Out:
# <Axes: >

# %%
df['Time'].hist(bins=100)
# Out:
# <Axes: >

# %%
import scipy

df['V1'].plot.kde()
# Out:
# <Axes: ylabel='Density'>
